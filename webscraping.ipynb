# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\manaswini karnataka\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\manaswini karnataka\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\manaswini karnataka\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manaswini karnataka\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manaswini karnataka\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manaswini karnataka\anaconda3\lib\site-packages (from requests) (2024.6.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manaswini karnataka\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd
import numpy as np

# %%
url = "https://www.jumia.com.ng/category-fashion-by-jumia/"
response = requests.get(url)
response.content
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131}button,html{font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}body a{color:#fff}body a:hover{color:#ee730a;text-decoration:underline}body .lds-ring div{border-color:#999 transparent transparent}body .font-red{color:#b20f03}body .pow-button{background-color:#4693ff;color:#1d1d1d}body #challenge-success-text{background-image:url(data:image/svg+xml;base64,...)}body #challenge-error-text{background-image:url(data:image/svg+xml;base64,...)}}body{display:flex;flex-direction:column;min-height:100vh}body.no-js .loading-spinner{visibility:hidden}body.no-js .challenge-running{display:none}body.dark{background-color:#222;color:#d9d9d9}body.dark a{color:#fff}body.dark a:hover{color:#ee730a;text-decoration:underline}body.dark .lds-ring div{border-color:#999 transparent transparent}body.dark .font-red{color:#b20f03}body.dark .pow-button{background-color:#4693ff;color:#1d1d1d}body.dark #challenge-success-text{background-image:url(data:image/svg+xml;base64,...)}body.dark #challenge-error-text{background-image:url(data:image/svg+xml;base64,...)}body.light{background-color:transparent;color:#313131}body.light a{color:#0051c3}body.light a:hover{color:#ee730a;text-decoration:underline}body.light .lds-ring div{border-color:#595959 transparent transparent}body.light .font-red{color:#fc574a}body.light .pow-button{background-color:#003681;border-color:#003681;color:#fff}body.light #challenge-success-text{background-image:url(data:image/svg+xml;base64,...)}body.light #challenge-error-text{background-image:url(data:image/svg+xml;base64,...)}a{background-color:transparent;color:#0051c3;text-decoration:none;transition:color .15s ease}a:hover{color:#ee730a;text-decoration:underline}.main-content{margin:8rem auto;max-width:60rem;width:100%}.heading-favicon{height:2rem;margin-right:.5rem;width:2rem}@media (width <= 720px){.main-content{margin-top:4rem}.heading-favicon{height:1.5rem;width:1.5rem}}.footer,.main-content{padding-left:1.5rem;padding-right:1.5rem}.main-wrapper{align-items:center;display:flex;flex:1;flex-direction:column}.font-red{color:#b20f03}.spacer{margin:2rem 0}.h1{font-size:2.5rem;font-weight:500;line-height:3.75rem}.h2{font-weight:500}.core-msg,.h2{font-size:1.5rem;line-height:2.25rem}.body-text,.core-msg{font-weight:400}.body-text{font-size:1rem;line-height:1.25rem}@media (width <= 720px){.h1{font-size:1.5rem;line-height:1.75rem}.h2{font-size:1.25rem}.core-msg,.h2{line-height:1.5rem}.core-msg{font-size:1rem}}#challenge-error-text{background-image:url(data:image/svg+xml;base64,...);padding-left:34px}#challenge-error-text,#challenge-success-text{background-repeat:no-repeat;background-size:contain}#challenge-success-text{background-image:url(data:image/svg+xml;base64,...);padding-left:42px}.text-center{text-align:center}.pow-button{background-color:#0051c3;border:.063rem solid #0051c3;border-radius:.313rem;color:#fff;font-size:.875rem;line-height:1.313rem;margin:2rem 0;padding:.375rem 1rem;transition-duration:.2s;transition-property:background-color,border-color,color;transition-timing-function:ease}.pow-button:hover{background-color:#003681;border-color:#003681;color:#fff;cursor:pointer}.footer{font-size:.75rem;line-height:1.125rem;margin:0 auto;max-width:60rem;width:100%}.footer-inner{border-top:1px solid #d9d9d9;padding-bottom:1rem;padding-top:1rem}.clearfix:after{clear:both;content:"";display:table}.clearfix .column{float: ...

# %%
import time

# Initialize lists to store product information
name_info = []
price_info = []
rating_info = []

# User-Agent header to mimic a web browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}


# Number of pages to scrape
num_pages = 50
for page in range(1, num_pages + 1):
    url = f"https://www.jumia.com.ng/category-fashion-by-jumia/?page={page}#catalog-listing"
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        print(f"Successfully fetched the webpage for page {page}")
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Locate the product details within the HTML
        product_containers = soup.find_all('article', class_='prd _fb col c-prd')
        
        for product in product_containers:
            name_tag = product.find('h3', class_='name')
            price_tag = product.find('div', class_='prc')
            rating_tag = product.find('div', class_='stars _s')
            
            # Extract and clean text only if the elements are found
            if name_tag and price_tag:
                name = name_tag.text.strip()
                price = price_tag.text.strip()
                rating = rating_tag.text.strip() if rating_tag else "No rating"
                
                name_info.append(name)
                price_info.append(price)
                rating_info.append(rating)
                
        # Adding a delay between requests to prevent being blocked
        time.sleep(1)
    else:
        print(f"Failed to fetch the webpage for page {page}", response.status_code)
        break
# Out:
# Successfully fetched the webpage for page 1
# Successfully fetched the webpage for page 2
# Successfully fetched the webpage for page 3
# Successfully fetched the webpage for page 4
# Successfully fetched the webpage for page 5
# Successfully fetched the webpage for page 6
# Successfully fetched the webpage for page 7
# Successfully fetched the webpage for page 8
# Successfully fetched the webpage for page 9
# Successfully fetched the webpage for page 10
# Successfully fetched the webpage for page 11
# Successfully fetched the webpage for page 12
# Successfully fetched the webpage for page 13
# Successfully fetched the webpage for page 14
# Successfully fetched the webpage for page 15
# Successfully fetched the webpage for page 16
# Successfully fetched the webpage for page 17
# Successfully fetched the webpage for page 18
# Successfully fetched the webpage for page 19
# Successfully fetched the webpage for page 20
# Successfully fetched the webpage for page 21
# Successfully fetched the webpage for page 22
# Successfully fetched the webpage for page 23
# Successfully fetched the webpage for page 24
# Successfully fetched the webpage for page 25
# Successfully fetched the webpage for page 26
# Successfully fetched the webpage for page 27
# Successfully fetched the webpage for page 28
# Successfully fetched the webpage for page 29
# Successfully fetched the webpage for page 30
# Successfully fetched the webpage for page 31
# Successfully fetched the webpage for page 32
# Successfully fetched the webpage for page 33
# Successfully fetched the webpage for page 34
# Successfully fetched the webpage for page 35
# Successfully fetched the webpage for page 36
# Successfully fetched the webpage for page 37
# Successfully fetched the webpage for page 38
# Successfully fetched the webpage for page 39
# Successfully fetched the webpage for page 40
# Successfully fetched the webpage for page 41
# Successfully fetched the webpage for page 42
# Successfully fetched the webpage for page 43
# Successfully fetched the webpage for page 44
# Successfully fetched the webpage for page 45
# Successfully fetched the webpage for page 46
# Successfully fetched the webpage for page 47
# Successfully fetched the webpage for page 48
# Successfully fetched the webpage for page 49
# Successfully fetched the webpage for page 50

# %%
# Print the results (you can modify this part as needed)
print("Product Names:", name_info)
print("Product Prices:", price_info)
print("Product Ratings:", rating_info)
# Out:
# Product Names: ["T-Shirts +Shorts 100% Cotton Men's Short Sleeve Set-White", '4 Pcs Women Bags Handbags Purse Ladies Bags Shoulder Bags', 'Monospec Sneakers - White', '3 PCS Women Bags Handbags Ladies Bags Purse Hobo Bags', 'Mens Casual High-Top Shoes Running Sneakers - Beige', 'N013 Ladies Luxurious Elegant Love Button Necklace-Gold-like', 'Danami Button Designed Long Sleeve T-Shirt- Light/Sky Blue', 'ADIDAS Advantage Shoes Men', 'Best Friends Love Heart Couple Necklace. Jewelry 2', 'ADIDAS Lucifo M MEN', 'ADIDAS Core Sneakers Advantage Base', 'ADIDAS WideWalk Sneakers', 'ADIDAS WideWalk Sneakers', '2in1 Fitted Stock Jeans For Men-Black + Blue', 'ADIDAS Essentials Embroidered Small Logo T-Shirt Men', "Men's Casual Short-sleeved Summer T-shirt", '3 Nose Rings Non Piercing Fake Magnetic Horseshoe-gold/silver/black', 'ADIDAS Advantage Lifestyle Court Lace Shoes', 'ADIDAS Streetcheck Cloudfoam Court Low Shoes Men', 'ADIDAS Essentials Embroidered Small Logo T-Shirt Men', 'ADIDAS Alliver M', 'ADIDAS BreezeWalk W WOMEN', 'ADIDAS GlideEase W WOMEN', 'ADIDAS Altaventure Sport Swim Sandals Unisex', "ASHION 2024 Men's Casual Shoes Big Size 39-47", 'Men Shoes Sneakers Sport Shoes Running Sneakers Casual Shoes', "Men's Anti-Slip Sandals Flip-Flop Slipper Shoes", 'Men Shoes Sneakers Sport Shoes Running Sneakers Casual Shoes  Welcome To Smark', "VEJARO LS01 Men's Casual Long Sleeve Plaid Shirt - Black", 'Six Pieces-in-1 Quality Ankle Socks', '2 In 1 Men T-shirts 2 PCS Tshirts Men Shorts Men Suits', '2024 Mens Casual Sci-Fi Warrior Shoes Running Sneakers - Black/Green', 'SILICONE LED DIGITAL SPORTS ELECTRONICS WRISTWATCH - UNISEX 0013', 'ADIDAS Adilette Aqua Slides Women', 'ADIDAS Core Sneakers Kids Grand Court K', 'Suede Mid-ankle Comfy Shoe Sneakers - Black', 'Mid-Sole Denim Sneakers - Sky Blue', 'Sports Canvas Fashion Sneakers - Grey', 'EILIFINTE Quality 3 IN
5', '4.4 out of 5', '3.4 out of 5', '4.1 out of 5', '3.2 out of 5', '4.3 out of 5', '4.1 out of 5', '4.5 out of 5', '4.4 out of 5', '3.7 out of 5', '3.1 out of 5', '3.4 out of 5', '4 out of 5', '4.4 out of 5', '3.5 out of 5', '4.6 out of 5', '3.2 out of 5', '4.4 out of 5', '4.3 out of 5', '4.4 out of 5', '3.9 out of 5', '3.8 out of 5', '4.2 out of 5', '4 out of 5', '3.5 out of 5', '4.1 out of 5', '3 out of 5', '4.4 out of 5', '4.1 out of 5', '4.6 out of 5', '3.3 out of 5', '4 out of 5', '3.8 out of 5', '3.9 out of 5', '3.9 out of 5', '4.1 out of 5', '3.9 out of 5', '3.9 out of 5', '4.3 out of 5', '3.5 out of 5', '4 out of 5', '3.4 out of 5', '4.5 out of 5', '3.9 out of 5', '3.9 out of 5', '4.2 out of 5', '4.2 out of 5', '3.4 out of 5', '3.9 out of 5', '3.3 out of 5', '3.8 out of 5', '4 out of 5', '3.9 out of 5', '4 out of 5', '4.3 out of 5', '3.9 out of 5', '3.1 out of 5', '4.1 out of 5', '3.6 out of 5', '4.2 out of 5', '3.7 out of 5', '4.2 out of 5', '3.7 out of 5', '3.7 out of 5', '4 out of 5', '3.7 out of 5', '4.5 out of 5', '3.9 out of 5', '3.9 out of 5', '4.4 out of 5', '3.9 out of 5', '4.1 out of 5', '3.8 out of 5', '4.1 out of 5', '4.1 out of 5', '3.5 out of 5', '4 out of 5', '3.9 out of 5', '3.6 out of 5', '4.1 out of 5', '4.2 out of 5', '4.2 out of 5', '4.2 out of 5', '4.1 out of 5', '3.5  ...

# %%
dict={'Product Name':name_info,'Price':price_info,'Rating':rating_info}

# %%
df=pd.DataFrame(dict)
df
# Out:
#                                            Product Name                Price  \
# 0     T-Shirts +Shorts 100% Cotton Men's Short Sleev...              ₦ 8,950
# 1     4 Pcs Women Bags Handbags Purse Ladies Bags Sh...              ₦ 6,281
# 2                             Monospec Sneakers - White             ₦ 12,155
# 3     3 PCS Women Bags Handbags Ladies Bags Purse Ho...              ₦ 7,862
# 4     Mens Casual High-Top Shoes Running Sneakers - ...             ₦ 16,900
# ...                                                 ...                  ...
# 1995                Crocs Yukon Crocs Clogs-light Brown             ₦ 50,000
# 1996  2 In 1 Kids Classic Waterproof  Children Wrist...              ₦ 3,999
# 1997  3 In 1 Quality Mens Chinos Trousers- Black + G...  ₦ 35,055 - ₦ 35,910
# 1998           DUBIA LUXURY UNISEX JAGUAR GOLD BRACELET              ₦ 6,999
# 1999                Kids New Sports Breathable Sneakers              ₦ 9,975
#
#             Rating
# 0     3.5 out of 5
# 1     3.4 out of 5
# 2       4 out of 5
# 3     3.6 out of 5
# 4     4.3 out of 5
# ...            ...
# 1995    5 out of 5
# 1996  4.1 out of 5
# 1997  3.8 out of 5
# 1998  2.7 out of 5
# 1999    5 out of 5
#
# [2000 rows x 3 columns]

# %%
df.to_csv('category_fashion_by_jumia.csv',index=False,encoding='utf-8')
